# %%
import pandas as pd
from datetime import datetime

# %%
file = ['bitcoin', 'dow', 'euro_stoxx50', 'nasdaq', 'nikkei', 'oro', 'petroleo', 'shangai_stock_exchange', 'sp_500']
data = []
for i in file:
    data.append(pd.read_csv('./data/' + i + '.csv'))

# %%
for i in data:
    print(i.info(), '\n \n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
# Fecha       2193 non-null object
# Cierre      2193 non-null object
# Apertura    2193 non-null object
# Máximo      2193 non-null object
# Mínimo      2193 non-null object
# Vol.        2193 non-null object
# % var.      2193 non-null object
# dtypes: object(7)
# memory usage: 120.0+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 7 columns):
# Fecha       1125 non-null object
# Cierre      1125 non-null float64
# Apertura    1125 non-null float64
# Máximo      1125 non-null float64
# Mínimo      1125 non-null float64
# Vol.        1125 non-null object
# % var.      1125 non-null object
# dtypes: float64(4), object(3)
# memory usage: 61.6+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1539 entries, 0 to 1538
# Data columns (total 7 columns):
# Fecha       1539 non-null object
# Cierre      1539 non-null object
# Apertura    1539 non-null object
# Máximo      1539 non-null object
# Mínimo      1539 non-null object
# Vol.        1539 non-null object
# % var.      1539 non-null object
# dtypes: object(7)
# memory usage: 84.2+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 7 columns):
# Fecha       1512 non-null object
# Cierre      1512 non-null float64
# Apertura    1512 non-null float64
# Máximo      1512 non-null float64
# Mínimo      1512 non-null float64
# Vol.        1512 non-null object
# % var.      1512 non-null object
# dtypes: float64(4), object(3)
# memory usage: 82.8+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1494 entries, 0 to 1493
# Data columns (total 7 columns):
# Fecha       1494 non-null object
# Cierre      1494 non-null object
# Apertura    1494 non-null object
# Máximo      1494 non-null object
# Mínimo      1494 non-null object
# Vol.        1494 non-null object
# % var.      1494 non-null object
# dtypes: object(7)
# memory usage: 81.8+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1588 entries, 0 to 1587
# Data columns (total 7 columns):
# Fecha       1588 non-null object
# Cierre      1588 non-null object
# Apertura    1588 non-null object
# Máximo      1588 non-null object
# Mínimo      1588 non-null object
# Vol.        1588 non-null object
# % var.      1588 non-null object
# dtypes: object(7)
# memory usage: 86.9+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1583 entries, 0 to 1582
# Data columns (total 7 columns):
# Fecha       1583 non-null object
# Cierre      1583 non-null float64
# Apertura    1583 non-null float64
# Máximo      1583 non-null float64
# Mínimo      1583 non-null float64
# Vol.        1583 non-null object
# % var.      1583 non-null object
# dtypes: float64(4), object(3)
# memory usage: 86.6+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1434 entries, 0 to 1433
# Data columns (total 7 columns):
# Fecha       1434 non-null object
# Cierre      1434 non-null float64
# Apertura    1434 non-null float64
# Máximo      1434 non-null float64
# Mínimo      1434 non-null float64
# Vol.        1434 non-null object
# % var.      1434 non-null object
# dtypes: float64(4), object(3)
# memory usage: 78.5+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 7 columns):
# Fecha       1511 non-null object
# Cierre      1511 non-null object
# Apertura    1511 non-null object
# Máximo      1511 non-null object
# Mínimo      1511 non-null object
# Vol.        1511 non-null object
# % var.      1511 non-null object
# dtypes: object(7)
# memory usage: 82.7+ KB
# None

# %%
def price(data):
    try:
        amount = [float(i.replace(',','')) for i in data.Cierre]
        df = pd.DataFrame({'date': pd.to_datetime(data.Fecha),
                      'amount': amount})
    except:
        df = pd.DataFrame({'date':pd.to_datetime(data.Fecha),
                      'amount': data.Cierre.astype('float')})
    return df

def variance(data):
    var = [float(i.replace('%','')) for i in data.iloc[:,6]]
    df = pd.DataFrame({'date': pd.to_datetime(data.Fecha),
                      'var': var})
    return df

def generate_df(l, names):
    inner = pd.merge(amount[0], amount[1], how ='inner', on = 'date', left_on = None, right_on = None,
         left_index = True, right_index = True, sort = True)
    for i in range(2, len(l)):
        inner = pd.merge(inner, amount[i], how ='inner', on = 'date', left_on = None, right_on = None,
                 left_index = True, right_index = True, sort = True)
    inner = pd.DataFrame(inner)
    inner.columns = names.insert(0, 'date')
    return inner

# %%
type(generate_df(amount, file).columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-e3ef1bbec640> in <module>
# ----> 1 type(generate_df(amount, file).columns)
#
# <ipython-input-70-b223157a5de4> in generate_df(l, names)
#      22                  left_index = True, right_index = True, sort = True)
#      23     inner = pd.DataFrame(inner)
# ---> 24     inner.columns = names.insert(0, 'date')
#      25     return inner
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     146
#     147     def set_axis(self, axis, new_labels):
# --> 148         new_labels = ensure_index(new_labels)
#     149         old_len = len(self.axes[axis])
#     150         new_len = len(new_labels)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5376             index_like = copy(index_like)
#    5377
# -> 5378     return Index(index_like)
#    5379
#    5380
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     466                          **kwargs)
#     467         elif data is None or is_scalar(data):
# --> 468             cls._scalar_data_error(data)
#     469         else:
#     470             if tupleize_cols and is_list_like(data):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#    3797         raise TypeError('{0}(...) must be called with a collection of some '
#    3798                         'kind, {1} was passed'.format(cls.__name__,
# -> 3799                                                       repr(data)))
#    3800
#    3801     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, None was passed

# %%
amount = []
var = []
for i in data:
    amount.append(price(i))
    var.append(variance(i))

# %%
amount[0].head(5)
# Out:
#         date   amount
# 0 2021-01-01  29359.9
# 1 2020-12-31  28949.4
# 2 2020-12-30  28868.7
# 3 2020-12-29  27376.0
# 4 2020-12-28  27057.8

# %%
var[0].head(5)
# Out:
#         date   var
# 0 2021-01-01  1.42
# 1 2020-12-31  0.28
# 2 2020-12-30  5.45
# 3 2020-12-29  1.18
# 4 2020-12-28  3.03

# %%
for i in amount:
    print('max: ', i.date.max(), '\t min: ', i.date.min())
# Out:
# max:  2021-01-01 00:00:00 	 min:  2015-01-01 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-04 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-04 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-04 00:00:00
# max:  2020-12-30 00:00:00 	 min:  2015-01-04 00:00:00
# max:  2021-01-01 00:00:00 	 min:  2015-01-01 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-01 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-04 00:00:00
# max:  2020-12-31 00:00:00 	 min:  2015-01-04 00:00:00

# %%
# Out:
#          date_x  amount_x     date_y  amount_y
# 0    2021-01-01   29359.9 2020-12-31     55.50
# 1    2020-12-31   28949.4 2020-12-30     55.47
# 2    2020-12-30   28868.7 2020-12-29     54.33
